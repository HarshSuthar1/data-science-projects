# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import seaborn as sns

# %%
data = pd.read_csv("heart_disease_health_indicators_BRFSS2015.csv")
data.head()
data = data.sort_values(by='BMI')

# %%
data.columns
# Out:
# Index(['HeartDiseaseorAttack', 'HighBP', 'HighChol', 'CholCheck', 'BMI',
#        'Smoker', 'Stroke', 'Diabetes', 'PhysActivity', 'Fruits', 'Veggies',
#        'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost', 'GenHlth',
#        'MentHlth', 'PhysHlth', 'DiffWalk', 'Sex', 'Age', 'Education',
#        'Income'],
#       dtype='object')

# %%
# data.Smoker.value_counts()
# corr = data[:5].corr()

sns.pairplot(data[['HeartDiseaseorAttack','Sex','Age','Stroke','Smoker','BMI']].corr())

# %%
X_data = data.drop(columns=["HeartDiseaseorAttack"])

# %%
y_data = data.HeartDiseaseorAttack

# %%
X = np.array(X_data.BMI).reshape(-1,1)

# %%
model = LogisticRegression()
model.fit(X,y_data)
# Out:
# LogisticRegression()

# %%
preds = model.predict_proba(X)

# print(preds[0])

new_preds = [i[0] for i in preds]

# %%
model.score(X,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model.score()
#
# TypeError: ClassifierMixin.score() missing 2 required positional arguments: 'X' and 'y'

# %%
plt.plot(X_data.BMI,new_preds)
